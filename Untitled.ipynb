# %%
from simsopt.geo import OrientedCurve
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from simsopt.geo import OrientedCurve
#
# ImportError: cannot import name 'OrientedCurve' from 'simsopt.geo' (/Users/rohanlopez/Github/simsopt/simsopt/src/simsopt/geo/__init__.py)
